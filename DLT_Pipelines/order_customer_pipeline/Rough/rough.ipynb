# %%
# %sql
select * from customer_orders.default.customer_scd2_bronze;

insert into demo.bronze.bronze_customers values(2,"Amit","Pune");

select * from demo.bronze.bronze_customers;

# %%
# %sql
select * from demo.bronze.bronze_customers;

# %%
# %sql
select * from customer_orders.default.customer_scd2_bronze;

# %%
# %sql
select * from customer_orders.default.customer_scd2_bronze;

# %%
# %sql
select * from customer_orders.default.customer_scd2_bronze;

# %%
# %sql
select * from customer_orders.default.order_customer_join;

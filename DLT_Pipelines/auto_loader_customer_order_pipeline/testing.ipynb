# %%
# %sql
select * from customer_orders.autoloader_demo.bronze_customers;

# %%
# %sql
select * from customer_orders.autoloader_demo.bronze_orders;

# %%
# %sql
select * from customer_orders.autoloader_demo.gold_customer_orders;

# %%
# %sql
select * from customer_orders.autoloader_demo.silver_customers_scd2;

# %%
# %sql
select * from customer_orders.autoloader_demo.silver_orders_scd1;

# %%
# %sql
select * from customer_orders.autoloader_demo.silver_orders_scd1;

# %%
# %sql
select * from customer_orders.autoloader_demo.gold_customer_orders;

# %%
# %sql
select * from customer_orders.autoloader_demo.silver_customers_scd2;

# %%
# %sql
select * from customer_orders.autoloader_demo.silver_customers_scd2;

# %%
# %sql
select * from customer_orders.autoloader_demo.silver_customers_scd2 where `__END_AT` is null;

# %%
# %sql
select * from customer_orders.autoloader_demo.bronze_orders;

# %%
# %sql
select * from customer_orders.autoloader_demo.silver_orders_scd1;

# %%
# %sql
select * from customer_orders.autoloader_demo.bronze_customers;

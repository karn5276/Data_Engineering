-- %% [markdown]
-- https://docs.delta.io/delta-clustering/

-- %%
%sql
CREATE OR REPLACE TABLE demo.default.liquide_clust_table
as SELECT * from samples.wanderbricks.employees;

-- %%
select * from demo.default.liquide_clust_table;

-- %%
select * from demo.default.liquide_clust_table where employee_id=23512;

-- %%
alter table demo.default.liquide_clust_table cluster by (employee_id)

-- %%
select * from demo.default.liquide_clust_table where employee_id=23512;

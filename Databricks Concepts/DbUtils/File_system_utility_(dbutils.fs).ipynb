# %%
dbutils.fs.help()

# %%
dbutils.fs.help("mount")

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/raw_data/input")

# %%
display(dbutils.fs.ls("/Volumes/workspace/default/raw_data"))

# %%
dbutils.fs.cp("dbfs:/Volumes/workspace/default/raw_data/orders.csv","dbfs:/Volumes/workspace/default/raw_data/input/")

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/default/raw_data/input/")

# %%
dbutils.fs.head("dbfs:/Volumes/workspace/default/raw_data/orders.csv") # cat enitre file

# %%
dbutils.fs.head("dbfs:/Volumes/workspace/default/raw_data/orders.csv",300)

# %%
dbutils.fs.rm("dbfs:/Volumes/workspace/default/raw_data/input/orders.csv")

# %%
dbutils.fs.rm("dbfs:/Volumes/workspace/default/raw_data/input",True) # True for recursive delete of all files in the directory.

# %%
# put(file: String, contents: String, overwrite: boolean = false): boolean

# this command overwrite entire file if file is not there then it create a file and add that contents in the file , but it never append data in existing file.

# if file is there then overwrite option must be True if not then it can False.
dbutils.fs.put("dbfs:/Volumes/workspace/default/raw_data/input/orders.csv","1,2,3,4,5",False)
dbutils.fs.head("dbfs:/Volumes/workspace/default/raw_data/input/orders.csv")

# %%
list1 = [1,[2,3],[1,4,4],5]
list2=[]
for i in list1:
    if(type(i)==int):
        list2.append([i])
    else:
        list2.append(i)

dict1 = {}
         
for i in list2:
    for j in i:
        dict1[j] = dict1.get(j, 0) + 1
        
print(dict1)
